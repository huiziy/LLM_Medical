# %%
import pandas as pd
import json

# %%
import os
import pandas as pd

# Set the directory where your CSV files are located
folder_path = '/Users/huiziyu/Library/CloudStorage/GoogleDrive-huiziy@g.ucla.edu/My Drive/Project - LLM in Biomedical & Health/new_data/'

# Initialize an empty DataFrame to store the combined data
combined_data = pd.DataFrame()

# Iterate through files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        # Read each CSV file into a DataFrame
        file_path = os.path.join(folder_path, filename)
        df = pd.read_csv(file_path)
        
        # Append the data to the combined DataFrame
        combined_data = combined_data.append(df, ignore_index=True)

# Save the combined data to a new CSV file
# combined_data.to_csv('combined_data.csv', index=False)
# Out:
# /Users/huiziyu/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3369: DtypeWarning: Columns (12,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
combined_data
# Out:
#                                      id  \
# 0      https://openalex.org/W4319662928
# 1      https://openalex.org/W4319460874
# 2      https://openalex.org/W4318931874
# 3      https://openalex.org/W4313451803
# 4      https://openalex.org/W4322761615
# ...                                 ...
# 17961  https://openalex.org/W4386700994
# 17962  https://openalex.org/W4386767417
# 17963  https://openalex.org/W4387702119
# 17964  https://openalex.org/W4377023047
# 17965  https://openalex.org/W4377253533
#
#                                             display_name publication_date  \
# 0      Performance of ChatGPT on USMLE: Potential for...       2023-02-09
# 1      How Does ChatGPT Perform on the United States ...       2023-02-08
# 2              ChatGPT and the Future of Medical Writing       2023-04-01
# 3      Performance of ChatGPT on USMLE: Potential for...       2022-12-20
# 4      The Role of ChatGPT, Generative Language Model...       2023-03-06
# ...                                                  ...              ...
# 17961  Applying GPT-4 to the Plastic Surgery Inservic...       2023-12-01
# 17962  ChatGPT for low- and middle-income countries: ...       2023-12-01
# 17963  Interpretable Disease Prediction via Path Reas...       2023-12-01
# 17964  ChatGPT (Generated Pre-Trained Transformer) As...       2023-12-31
# 17965  4 The Third Vector: Pacific Pathogens, Colonia...       2023-12-31
#
#        relevance_score               primary_location_id  \
# 0           1018.67914  https://openalex.org/S4210221150
# 1            702.65290  https://openalex.org/S4210212741
# 2            430.05685    https://openalex.org/S50280174
# 3            382.76773  https://openalex.org/S4306400573
# 4            296.67730  https://openalex.org/S4210212741
# ...                ...                               ...
# 17961              NaN    https://openalex.org/S23813625
# 17962              NaN  https://openalex.org/S4210225048
# 17963              NaN    https://openalex.org/S10169007
# 17964              NaN  https://openalex.org/S4210236781
# 17965              NaN  https://openalex.org/S4306464165
#
#                            primary_location_display_name  \
# 0                                    PLOS digital health
# 1                                 JMIR medical education
# 2                                              Radiology
# 3                medRxiv (Cold Spring Harbor Laboratory)
# 4                                 JMIR medical education
# ...                                                  ...
# 17961  Journal of Plastic Reconstructive and Aestheti...
# 17962       The Lancet Regional Health - Western Pacific
# 17963                            Knowledge Based Systems
# 17964  International journal of psychology and psycho...
# 17965                  University of Hawaii Press eBooks
#
#           primary_location_host_organization primary_location_issns  \
# 0                  Public Library of Science              2767-3170
# 1                          JMIR Publications              2369-3762
# 2      Radiological Society of North America    1527-1315|0033-8419
# 3              Cold Spring Harbor Laboratory                    NaN
# 4                          JMIR Publications              2369-3762
# ...                                      ...                    ...
# 17961                            Elsevier BV    1878-0539|1748-6815
# 17962                            Elsevier BV              2666-6065
# 17963                            Elsevier BV    1872-7409|0950-7051
# 17964                                    NaN              2572-4037
# 17965                                    NaN                    NaN
#
#       primary_location_issn_l primary_location_type  ...          type  \
# 0                   2767-3170               journal  ...       article
# 1                   2369-3762               journal  ...       article
# 2                   0033-8419               journal  ...       article
# 3                         NaN            repository  ...       article
# 4                   2369-3762               journal  ...       article
# ...                       ...                   ...  ...           ...
# 17961               1748-6815               journal  ...       article
# 17962               2666-6065               journal  ...       article
# 17963               0950-7051               journal  ...       article
# 17964               2572-4037               journal  ...       article
# 17965                     NaN        ebook platform  ...  book-chapter
#
#       is_paratext is_retracted biblio_issue biblio_first_page biblio_volume  \
# 0           False        False            2          e0000198             2
# 1           False        False          NaN            e45312             9
# 2           False        False            2               NaN           307
# 3           False        False          NaN               NaN           NaN
# 4           False        False          NaN            e46885             9
# ...           ...          ...          ...               ...           ...
# 17961       False        False          NaN                78            87
# 17962       False        False          NaN            100906            41
# 17963       False        False          NaN            111082           281
# 17964       False        False            1               NaN             9
# 17965       False        False          NaN                68           NaN
#
#       biblio_last_page                                   referenced_works  \
# 0             e0000198  https://openalex.org/W94062176|https://openale...
# 1               e45312  https://openalex.org/W61072347|https://openale...
# 2                  NaN  https://openalex.org/W4310917376|https://opena...
# 3                  NaN  https://openalex.org/W2183341477|https://opena...
# 4               e46885                   https://openalex.org/W4319460874
# ...                ...                                                ...
# 17961               82  https://openalex.org/W61072347|https://openale...
# 17962           100906  https://openalex.org/W3092635044|https://opena...
# 17963           111082  https://openalex.org/W236448318|https://openal...
# 17964              NaN                                                NaN
# 17965               85                                                NaN
#
#                                            related_works  \
# 0      https://openalex.org/W1980938344|https://opena...
# 1      https://openalex.org/W1986582023|https://opena...
# 2      https://openalex.org/W1506200166|https://opena...
# 3      https://openalex.org/W1973750112|https://opena...
# 4      https://openalex.org/W2019424700|https://opena...
# ...                                                  ...
# 17961  https://openalex.org/W1552490082|https://opena...
# 17962  https://openalex.org/W2899084033|https://opena...
# 17963  https://openalex.org/W1986582023|https://opena...
# 17964  https://openalex.org/W1531808129|https://opena...
# 17965  https://openalex.org/W1701366609|https://opena...
#
#                                              concept_ids
# 0      https://openalex.org/C160798450|https://openal...
# 1      https://openalex.org/C2781067378|https://opena...
# 2      https://openalex.org/C71924100|https://openale...
# 3      https://openalex.org/C160798450|https://openal...
# 4      https://openalex.org/C2777200299|https://opena...
# ...                                                  ...
# 17961  https://openalex.org/C71924100|https://openale...
# 17962  https://openalex.org/C83867959|https://openale...
# 17963  https://openalex.org/C2781067378|https://opena...
# 17964  https://openalex.org/C2777056012|https://opena...
# 17965  https://openalex.org/C531593650|https://openal...
#
# [17966 rows x 40 columns]

# %%
def inverted_index_to_sentence(inverted_index):
    # Create a list with None in the places of the words
    sentence_list = [None] * (max(max(indices) for indices in inverted_index.values()) + 1)

    # Place words in the correct order based on their indices
    for word, indices in inverted_index.items():
        for index in indices:
            sentence_list[index] = word

    # Join the list into a string to form a complete sentence, fill gaps with placeholder
    sentence = ' '.join(word if word is not None else '[...]' for word in sentence_list)

    return sentence

# %%
PATH_data_export = "/Users/huiziyu/Library/CloudStorage/GoogleDrive-huiziy@g.ucla.edu/My Drive/Project - LLM in Biomedical & Health/new_data/processed/"

### Setup openalex API
import pyalex
pyalex.config.email = "huiziy@umich.edu"
from pyalex import Works #, Authors, Sources, Institutions, Concepts, Publishers, Funders

# helpfer function with jsonl
def save_to_jsonl(data, file_name):
    with open(file_name, 'a') as f:
        f.write(json.dumps(data) + '\n')

all_works = []
file_name = "openalex_works.jsonl"
i_counter = 0

# Assuming you have a DataFrame named 'combined_data'
for _, row in combined_data.iterrows():
    i_counter += 1
    if i_counter % 1000 == 0:
        print(i_counter)

    this_work = {}
    if type(row['doi']) != float:
        try:
            this_work = Works()["https://doi.org/"+row['doi']]
        except:
            pass

    # Apply the inverted_index_to_text function and store the result in 'abstract_text'
    try:
        row['abstract_text'] = inverted_index_to_sentence(this_work['abstract_inverted_index'])
    except:
        pass

    # Append the row to the 'all_works' list
    all_works.append(row)

# Save the modified data to a JSON file
output_df = pd.DataFrame(all_works)
output_df.to_json(f'{PATH_data_export}/output_data.json', orient='records', lines=True)
output_df.to_csv(f'{PATH_data_export}/output_data.csv', index=False)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000

# %%
this_work['abstract_inverted_index']
