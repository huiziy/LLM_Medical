# %% [markdown]
# ## Remove Non-English documents & perform second round of cleaning (using Title and Abstract)

# %%
import pandas as pd
from langdetect import detect

# %%
PATH_data_export = "/Users/huiziyu/Library/CloudStorage/GoogleDrive-huiziy@g.ucla.edu/My Drive/Project - LLM in Biomedical & Health/new_data/processed/"

# %%
df = pd.read_csv(f'{PATH_data_export}/output_data.csv')

# %%
# replace na with ""
df.fillna("",inplace=True)
abstract_df = df[['display_name','doi','abstract_text']].reset_index(drop=True)
# We use title and abstract, as well focus on sentence-line context aware info, not keywords.
abstract_df["Title_abstract"] = abstract_df["display_name"]+". "+abstract_df["abstract_text"]
# now titel only
# abstract_df["Title_abstract"] = abstract_df["display_name"]

# %%
abstract_df
# Out:
#                                            display_name  \
# 0     Performance of ChatGPT on USMLE: Potential for...
# 1     How Does ChatGPT Perform on the United States ...
# 2     Performance of ChatGPT on USMLE: Potential for...
# 3     ChatGPT Utility in Healthcare Education, Resea...
# 4     ChatGPT and the rise of large language models:...
# ...                                                 ...
# 8755  Effect of Ramadan intermittent fasting on rena...
# 8756  Equity in Scientific Publishing: Can Artificia...
# 8757  Predicting seizure recurrence from medical rec...
# 8758  ChatGPT (Generated Pre-Trained Transformer) As...
# 8759  Chapter 9 Th e Impact of COVID-19 on Child Mar...
#
#                                                 doi  \
# 0      https://doi.org/10.1371/journal.pdig.0000198
# 1                     https://doi.org/10.2196/45312
# 2       https://doi.org/10.1101/2022.12.19.22283643
# 3        https://doi.org/10.3390/healthcare11060887
# 4        https://doi.org/10.3389/fpubh.2023.1166120
# ...                                             ...
# 8755      https://doi.org/10.1016/j.hnm.2023.200227
# 8756   https://doi.org/10.1016/j.mcpdig.2023.10.002
# 8757  https://doi.org/10.1016/s2589-7500(23)00205-4
# 8758     https://doi.org/10.23937/2572-4037.1510062
# 8759      https://doi.org/10.1515/9781800737792-011
#
#                                           abstract_text  \
# 0     We evaluated the performance of a large langua...
# 1     Background Chat Generative Pre-trained Transfo...
# 2     ABSTRACT We evaluated the performance of a lar...
# 3     ChatGPT is an artificial intelligence (AI)-bas...
# 4     Large Language Models (LLMs) have recently gat...
# ...                                                 ...
# 8755  Intermittent fasting (IF) has garnered attenti...
# 8756  Chat Generative Pre-Trained Transformer (ChatG...
# 8757  Physicians document a wealth of helpful inform...
# 8758  Mental health disorders affect one in four peo...
# 8759
#
#                                          Title_abstract
# 0     Performance of ChatGPT on USMLE: Potential for...
# 1     How Does ChatGPT Perform on the United States ...
# 2     Performance of ChatGPT on USMLE: Potential for...
# 3     ChatGPT Utility in Healthcare Education, Resea...
# 4     ChatGPT and the rise of large language models:...
# ...                                                 ...
# 8755  Effect of Ramadan intermittent fasting on rena...
# 8756  Equity in Scientific Publishing: Can Artificia...
# 8757  Predicting seizure recurrence from medical rec...
# 8758  ChatGPT (Generated Pre-Trained Transformer) As...
# 8759  Chapter 9 Th e Impact of COVID-19 on Child Mar...
#
# [8760 rows x 4 columns]

# %%
from langdetect import detect, LangDetectException

def safe_detect(text):
    # Check if the text is not empty and not just whitespace
    if text and text.strip():
        try:
            # Perform language detection
            return detect(text)
        except LangDetectException:
            # Return a default value or raise an error
            return ""
    else:
        # Return a default value for empty or whitespace-only strings
        return ""

# Applying the function
df_new = abstract_df[abstract_df.Title_abstract.apply(safe_detect).eq('en')]

# %%
df_new.to_csv(f'{PATH_data_export}/output_data_en.csv', index=False)

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8322 entries, 0 to 8759
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   display_name    8322 non-null   object
#  1   doi             8322 non-null   object
#  2   abstract_text   8322 non-null   object
#  3   Title_abstract  8322 non-null   object
# dtypes: object(4)
# memory usage: 325.1+ KB

# %%
file_path = f'{PATH_data_export}/doi_relevant.txt'

# Saving the 'Title_abstract' column to a text file
df_new['doi'].to_csv(file_path, index=False, header=False)

# %%
df_new
# Out:
#                                            display_name  \
# 0     Performance of ChatGPT on USMLE: Potential for...
# 1     How Does ChatGPT Perform on the United States ...
# 2     Performance of ChatGPT on USMLE: Potential for...
# 3     ChatGPT Utility in Healthcare Education, Resea...
# 4     ChatGPT and the rise of large language models:...
# ...                                                 ...
# 8755  Effect of Ramadan intermittent fasting on rena...
# 8756  Equity in Scientific Publishing: Can Artificia...
# 8757  Predicting seizure recurrence from medical rec...
# 8758  ChatGPT (Generated Pre-Trained Transformer) As...
# 8759  Chapter 9 Th e Impact of COVID-19 on Child Mar...
#
#                                                 doi  \
# 0      https://doi.org/10.1371/journal.pdig.0000198
# 1                     https://doi.org/10.2196/45312
# 2       https://doi.org/10.1101/2022.12.19.22283643
# 3        https://doi.org/10.3390/healthcare11060887
# 4        https://doi.org/10.3389/fpubh.2023.1166120
# ...                                             ...
# 8755      https://doi.org/10.1016/j.hnm.2023.200227
# 8756   https://doi.org/10.1016/j.mcpdig.2023.10.002
# 8757  https://doi.org/10.1016/s2589-7500(23)00205-4
# 8758     https://doi.org/10.23937/2572-4037.1510062
# 8759      https://doi.org/10.1515/9781800737792-011
#
#                                           abstract_text  \
# 0     We evaluated the performance of a large langua...
# 1     Background Chat Generative Pre-trained Transfo...
# 2     ABSTRACT We evaluated the performance of a lar...
# 3     ChatGPT is an artificial intelligence (AI)-bas...
# 4     Large Language Models (LLMs) have recently gat...
# ...                                                 ...
# 8755  Intermittent fasting (IF) has garnered attenti...
# 8756  Chat Generative Pre-Trained Transformer (ChatG...
# 8757  Physicians document a wealth of helpful inform...
# 8758  Mental health disorders affect one in four peo...
# 8759
#
#                                          Title_abstract
# 0     Performance of ChatGPT on USMLE: Potential for...
# 1     How Does ChatGPT Perform on the United States ...
# 2     Performance of ChatGPT on USMLE: Potential for...
# 3     ChatGPT Utility in Healthcare Education, Resea...
# 4     ChatGPT and the rise of large language models:...
# ...                                                 ...
# 8755  Effect of Ramadan intermittent fasting on rena...
# 8756  Equity in Scientific Publishing: Can Artificia...
# 8757  Predicting seizure recurrence from medical rec...
# 8758  ChatGPT (Generated Pre-Trained Transformer) As...
# 8759  Chapter 9 Th e Impact of COVID-19 on Child Mar...
#
# [8315 rows x 4 columns]

# %% [markdown]
# ## Second Round of Cleaning:
# Per OpenAlex help page: When you search works, the API looks for matches in titles, abstracts, ... For most text search we remove stop words and use stemming (specifically, the Kstem token filter) to improve results. This could result in non-relevant documents being included after stemming. So we perform a second round of cleaning to keep only documents that explicitly mention the query words in the title and abstract.
# Source: https://docs.openalex.org/how-to-use-the-api/get-lists-of-entities/search-entities

# %%
# Keywords
keywords_1 = ["large language model", "GPT", "gpt", "Large Language Model", "LLM"]
# keywords_2 = ["health", "medical", "Health", "Medical"]

# Checking if the Title_abstract field contains the keywords
# contains_keywords = df_new['Title_abstract'].apply(lambda x: any(kw in x for kw in keywords_1) and any(kw in x for kw in keywords_2))
contains_keywords = df_new['Title_abstract'].apply(lambda x: any(kw in x for kw in keywords_1))
df_relevant = df_new[contains_keywords]
df_relevant.to_csv(f'{PATH_data_export}data_relevant.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [11], in <cell line: 9>()
#       7 contains_keywords = df_new['Title_abstract'].apply(lambda x: any(kw in x for kw in keywords_1))
#       8 df_relevant = df_new[contains_keywords]
# ----> 9 df_relevant.to_csv(f'{PATH_data_export}data_relevant.csv', index=False)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:3466, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3455 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3457 formatter = DataFrameFormatter(
#    3458     frame=df,
#    3459     header=header,
#    (...)
#    3463     decimal=decimal,
#    3464 )
# -> 3466 return DataFrameRenderer(formatter).to_csv(
#    3467     path_or_buf,
#    3468     line_terminator=line_terminator,
#    3469     sep=sep,
#    3470     encoding=encoding,
#    3471     errors=errors,
#    3472     compression=compression,
#    3473     quoting=quoting,
#    3474     columns=columns,
#    3475     index_label=index_label,
#    3476     mode=mode,
#    3477     chunksize=chunksize,
#    3478     quotechar=quotechar,
#    3479     date_format=date_format,
#    3480     doublequote=doublequote,
#    3481     escapechar=escapechar,
#    3482     storage_options=storage_options,
#    3483 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/format.py:1105, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1084     created_buffer = False
#    1086 csv_formatter = CSVFormatter(
#    1087     path_or_buf=path_or_buf,
#    1088     line_terminator=line_terminator,
#    (...)
#    1103     formatter=self.fmt,
#    1104 )
# -> 1105 csv_formatter.save()
#    1107 if created_buffer:
#    1108     assert isinstance(path_or_buf, StringIO)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/csvs.py:237, in CSVFormatter.save(self)
#     233 """
#     234 Create the writer & save.
#     235 """
#     236 # apply compression and byte/text conversion
# --> 237 with get_handle(
#     238     self.filepath_or_buffer,
#     239     self.mode,
#     240     encoding=self.encoding,
#     241     errors=self.errors,
#     242     compression=self.compression,
#     243     storage_options=self.storage_options,
#     244 ) as handles:
#     245
#     246     # Note: self.encoding is irrelevant here
#     247     self.writer = csvlib.writer(
#     248         handles.handle,  # type: ignore[arg-type]
#     249         lineterminator=self.line_terminator,
#    (...)
#     254         quotechar=self.quotechar,
#     255     )
#     257     self._save()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py:702, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     697 elif isinstance(handle, str):
#     698     # Check whether the filename is to be opened in binary mode.
#     699     # Binary mode does not support 'encoding' and 'newline'.
#     700     if ioargs.encoding and "b" not in ioargs.mode:
#     701         # Encoding
# --> 702         handle = open(
#     703             handle,
#     704             ioargs.mode,
#     705             encoding=ioargs.encoding,
#     706             errors=errors,
#     707             newline="",
#     708         )
#     709     else:
#     710         # Binary mode
#     711         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/huiziyu/Library/CloudStorage/GoogleDrive-huiziy@g.ucla.edu/My Drive/Project - LLM in Biomedical & Health/new_data/processed/data_relevant.csv'

# %%
file_path = f'{PATH_data_export}/doi_relevant.txt'

# Saving the 'Title_abstract' column to a text file
df_relevant['doi'].to_csv(file_path, index=False, header=False)

# %%
## Total with keywords

# %%
contains_keywords.sum()
# Out:
# 3417

# %%
df_relevant
# Out:
#                                             display_name  \
# 0      Performance of ChatGPT on USMLE: Potential for...
# 1      How Does ChatGPT Perform on the United States ...
# 2              ChatGPT and the Future of Medical Writing
# 3      Performance of ChatGPT on USMLE: Potential for...
# 4      The Role of ChatGPT, Generative Language Model...
# ...                                                  ...
# 17959  Revolutionizing clinical experimental protocol...
# 17961  Applying GPT-4 to the Plastic Surgery Inservic...
# 17962  ChatGPT for low- and middle-income countries: ...
# 17963  Interpretable Disease Prediction via Path Reas...
# 17964  ChatGPT (Generated Pre-Trained Transformer) As...
#
#                                                 doi  \
# 0      https://doi.org/10.1371/journal.pdig.0000198
# 1                     https://doi.org/10.2196/45312
# 2             https://doi.org/10.1148/radiol.223312
# 3       https://doi.org/10.1101/2022.12.19.22283643
# 4                     https://doi.org/10.2196/46885
# ...                                             ...
# 17959   https://doi.org/10.1016/j.amjms.2023.09.004
# 17961    https://doi.org/10.1016/j.bjps.2023.09.027
# 17962  https://doi.org/10.1016/j.lanwpc.2023.100906
# 17963  https://doi.org/10.1016/j.knosys.2023.111082
# 17964    https://doi.org/10.23937/2572-4037.1510062
#
#                                            abstract_text  \
# 0      We evaluated the performance of a large langua...
# 1      Background Chat Generative Pre-trained Transfo...
# 2      HomeRadiologyVol. 307, No. 2 PreviousNext Revi...
# 3      ABSTRACT We evaluated the performance of a lar...
# 4      ChatGPT is a generative language model tool la...
# ...                                                  ...
# 17959  ChatGPT is a conversational artificial intelli...
# 17961  The recent introduction of Generative Pre-trai...
# 17962  ChatGPT (OpenAI, San Francisco, CA, USA) has m...
# 17963  Disease prediction based on patients’ historic...
# 17964  Mental health disorders affect one in four peo...
#
#                                           Title_abstract
# 0      Performance of ChatGPT on USMLE: Potential for...
# 1      How Does ChatGPT Perform on the United States ...
# 2      ChatGPT and the Future of Medical Writing. Hom...
# 3      Performance of ChatGPT on USMLE: Potential for...
# 4      The Role of ChatGPT, Generative Language Model...
# ...                                                  ...
# 17959  Revolutionizing clinical experimental protocol...
# 17961  Applying GPT-4 to the Plastic Surgery Inservic...
# 17962  ChatGPT for low- and middle-income countries: ...
# 17963  Interpretable Disease Prediction via Path Reas...
# 17964  ChatGPT (Generated Pre-Trained Transformer) As...
#
# [3417 rows x 4 columns]

# %%
df_without_keywords = df_new[~contains_keywords]
df_without_keywords.to_csv(f'{PATH_data_export}/nonrelevant_data.csv', index=False)
